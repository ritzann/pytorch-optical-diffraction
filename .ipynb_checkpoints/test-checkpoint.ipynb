# %%
# %matplotlib inline

import numpy as np
import torch
import matplotlib.pyplot as plt
from objects import Objects
from propagators import Propagate
from time import time

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
backend = torch
# Out:
# cuda

# %%
# Define physical parameters
aperture_size = 100e-6 # physical size of the aperture in meters
num_pixels = 2**8 # number of pixels
pixel_size = aperture_size / num_pixels # pixel size
photon_energy = 2.3305299436090226e6

O = Objects(device=device, backend=np)
O.create_2Darray(num_pixels,num_pixels)
circ = O.create_circle(r = 0.25, x0 = 0, y0 = 0)
rect = O.create_rect(0.1,0.1)
Uin = rect

# %%
Uin.shape
# Out:
# (256, 256)

# %% [raw]
# # only for torch backend
# print(circ.cpu().numpy().dtype)
# print(rect.cpu().numpy().dtype)
# plt.imshow(circ.cpu())
# plt.imshow(rect.cpu())
# print(circ.get_device())

# %%
test = torch.Tensor((2,2))
test.shape[-1]
num_pixels
# Out:
# 256

# %%
pos = 1e-3

device1 = torch.device("cuda" if torch.cuda.is_available() else "cpu")
start_torch = time()

P1 = Propagate(device=device1,
                     pixel_number=Uin.shape[0],
                     pixel_size=pixel_size)

prop_field1 = P1.rs_spectral(field_in=Uin,
                             pixel_number=Uin.shape[0],
                             pixel_size=pixel_size,
                             position=pos,
                             photon_energy=photon_energy,
                             has_evanescent=False,
                             reset=True,
                             pad = int(num_pixels))
end_torch = time()

device2 = "cpu"
start_numpy = time()
P2 = Propagate(device=device2,
                     pixel_number=Uin.shape[0],
                     pixel_size=pixel_size)

prop_field2 = P2.rs_spectral(field_in=Uin,
                             pixel_number=Uin.shape[0],
                             pixel_size=pixel_size,
                             position=pos,
                             photon_energy=photon_energy,
                             has_evanescent=False,
                             reset=True,
                             pad = int(num_pixels),
                             backend = np)
end_numpy = time()
# Out:
# cuda
# cpu
# /home/aguila72/miniconda3/envs/nfphasing/lib/python3.9/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3483.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
plt.imshow(np.abs(prop_field2))

# %%
print("Total Time:")
torch_diff = end_torch - start_torch
numpy_diff = end_numpy - start_numpy
print("Numpy: ", end_numpy - start_numpy, "seconds")
print("Torch: ", end_torch - start_torch, "seconds")
print("Torch is faster by",(numpy_diff - torch_diff)/numpy_diff*100,"% than Numpy for an image size of",num_pixels**2/10e6,"MP.")
# Out:
# Total Time:
# Numpy:  0.07419252395629883 seconds
# Torch:  1.2916462421417236 seconds
# Torch is faster by -1640.938538366122 % than Numpy for an image size of 0.0065536 MP.

# %%
import matplotlib.pyplot as plt
plt.imshow((np.abs(prop_field2)-np.abs(prop_field1.cpu().numpy())) / 
           (np.abs(prop_field2)+np.abs(prop_field1.cpu().numpy()))/2)
plt.colorbar()
print(prop_field2.dtype)
# Out:
# complex64

# %%
plt.imshow((np.abs(prop_field2)-np.abs(prop_field1.cpu().numpy())))
plt.colorbar()

# %%
print(prop_field2.shape)
print(type(prop_field2))

print(prop_field1.cpu().numpy().shape)
print(type(prop_field1.cpu().numpy()))
# Out:
# (768, 768)
# <class 'numpy.ndarray'>
# (768, 768)
# <class 'numpy.ndarray'>
